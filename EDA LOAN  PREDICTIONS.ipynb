# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df=pd.read_csv("C:\\Users\\Hp\\Downloads\\Loan_Data.csv")
df
# Out:
#       Loan_ID  Gender Married Dependents     Education Self_Employed  \
# 0    LP001002    Male      No          0      Graduate            No
# 1    LP001003    Male     Yes          1      Graduate            No
# 2    LP001005    Male     Yes          0      Graduate           Yes
# 3    LP001006    Male     Yes          0  Not Graduate            No
# 4    LP001008    Male      No          0      Graduate            No
# ..        ...     ...     ...        ...           ...           ...
# 609  LP002978  Female      No          0      Graduate            No
# 610  LP002979    Male     Yes         3+      Graduate            No
# 611  LP002983    Male     Yes          1      Graduate            No
# 612  LP002984    Male     Yes          2      Graduate            No
# 613  LP002990  Female      No          0      Graduate           Yes
#
#      ApplicantIncome  CoapplicantIncome  LoanAmount  Loan_Amount_Term  \
# ...

# %%
df.shape
# Out:
# (614, 13)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 614 entries, 0 to 613
# Data columns (total 13 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Loan_ID            614 non-null    object
#  1   Gender             601 non-null    object
#  2   Married            611 non-null    object
#  3   Dependents         599 non-null    object
#  4   Education          614 non-null    object
#  5   Self_Employed      582 non-null    object
#  6   ApplicantIncome    614 non-null    int64
#  7   CoapplicantIncome  614 non-null    float64
#  8   LoanAmount         592 non-null    float64
#  9   Loan_Amount_Term   600 non-null    float64
#  10  Credit_History     564 non-null    float64
#  11  Property_Area      614 non-null    object
#  12  Loan_Status        614 non-null    object
# dtypes: float64(4), int64(1), object(8)
# memory usage: 62.5+ KB

# %%
df.drop(["Loan_ID"],axis=1,inplace=True)

# %%
df=df.dropna()

# %%
continous=["CoapplicantIncome","LoanAmount","Loan_Amount_Term","Credit_History","ApplicantIncome"]
disrete=["Gender","Married","Dependents","Education","Self_Employed","Property_Area","Loan_Status"]

# %%
df[continous].describe()
# Out:
#        CoapplicantIncome  LoanAmount  Loan_Amount_Term  Credit_History  \
# count         480.000000  480.000000        480.000000      480.000000
# mean         1581.093583  144.735417        342.050000        0.854167
# std          2617.692267   80.508164         65.212401        0.353307
# min             0.000000    9.000000         36.000000        0.000000
# 25%             0.000000  100.000000        360.000000        1.000000
# 50%          1084.500000  128.000000        360.000000        1.000000
# 75%          2253.250000  170.000000        360.000000        1.000000
# max         33837.000000  600.000000        480.000000        1.000000
#
#        ApplicantIncome
# count       480.000000
# mean       5364.231250
# std        5668.251251
# min         150.000000
# 25%        2898.750000
# 50%        3859.000000
# 75%        5852.500000
# max       81000.000000

# %%
df.describe(include="object")
# Out:
#        Gender Married Dependents Education Self_Employed Property_Area  \
# count     480     480        480       480           480           480
# unique      2       2          4         2             2             3
# top      Male     Yes          0  Graduate            No     Semiurban
# freq      394     311        274       383           414           191
#
#        Loan_Status
# count          480
# unique           2
# top              Y
# freq           332

# %%
df.describe(include="all")
# Out:
#        Gender Married Dependents Education Self_Employed  ApplicantIncome  \
# count     480     480        480       480           480       480.000000
# unique      2       2          4         2             2              NaN
# top      Male     Yes          0  Graduate            No              NaN
# freq      394     311        274       383           414              NaN
# mean      NaN     NaN        NaN       NaN           NaN      5364.231250
# std       NaN     NaN        NaN       NaN           NaN      5668.251251
# min       NaN     NaN        NaN       NaN           NaN       150.000000
# 25%       NaN     NaN        NaN       NaN           NaN      2898.750000
# 50%       NaN     NaN        NaN       NaN           NaN      3859.000000
# 75%       NaN     NaN        NaN       NaN           NaN      5852.500000
# max       NaN     NaN        NaN       NaN           NaN     81000.000000
#
#         CoapplicantIncome  LoanAmount  Loan_Amount_Term  Credit_History  \
# ...

# %%
df
# Out:
#      Gender Married Dependents     Education Self_Employed  ApplicantIncome  \
# 1      Male     Yes          1      Graduate            No             4583
# 2      Male     Yes          0      Graduate           Yes             3000
# 3      Male     Yes          0  Not Graduate            No             2583
# 4      Male      No          0      Graduate            No             6000
# 5      Male     Yes          2      Graduate           Yes             5417
# ..      ...     ...        ...           ...           ...              ...
# 609  Female      No          0      Graduate            No             2900
# 610    Male     Yes         3+      Graduate            No             4106
# 611    Male     Yes          1      Graduate            No             8072
# 612    Male     Yes          2      Graduate            No             7583
# 613  Female      No          0      Graduate           Yes             4583
#
# ...

# %%
df["Gender"].value_counts()
# Out:
# Male      394
# Female     86
# Name: Gender, dtype: int64

# %%
df["Married"].value_counts()
# Out:
# Yes    311
# No     169
# Name: Married, dtype: int64

# %%
df["Dependents"].value_counts()
# Out:
# 0     274
# 2      85
# 1      80
# 3+     41
# Name: Dependents, dtype: int64

# %%
df["Dependents"].replace("3+",3,inplace=True)
df
# Out:
# C:\Users\Hp\AppData\Local\Temp\ipykernel_8460\325229248.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df["Dependents"].replace("3+",3,inplace=True)
#      Gender Married Dependents     Education Self_Employed  ApplicantIncome  \
# 1      Male     Yes          1      Graduate            No             4583
# 2      Male     Yes          0      Graduate           Yes             3000
# 3      Male     Yes          0  Not Graduate            No             2583
# 4      Male      No          0      Graduate            No             6000
# 5      Male     Yes          2      Graduate           Yes             5417
# ..      ...     ...        ...           ...           ...              ...
# 609  Female      No          0      Graduate            No             2900
# ...

# %%
df["Education"].value_counts()
# Out:
# Graduate        383
# Not Graduate     97
# Name: Education, dtype: int64

# %%
df["Self_Employed"].value_counts()
# Out:
# No     414
# Yes     66
# Name: Self_Employed, dtype: int64

# %%
df["Property_Area"].value_counts()
# Out:
# Semiurban    191
# Urban        150
# Rural        139
# Name: Property_Area, dtype: int64

# %%
df["Loan_Status"].value_counts()
# Out:
# Y    332
# N    148
# Name: Loan_Status, dtype: int64

# %%
sns.displot(df["CoapplicantIncome"],bins=10,kde=True)
plt.show()

# %%
sns.displot(df["LoanAmount"],bins=10,kde=True)
plt.show()

# %%
sns.displot(df["Loan_Amount_Term"],bins=10,kde=True)
plt.show()

# %%
sns.displot(df["Credit_History"],bins=10,kde=True)
plt.show()

# %%
sns.displot(df["ApplicantIncome"],bins=10,kde=True)
plt.show()

# %%
sns.boxplot(x=df["CoapplicantIncome"])
plt.show()

# %%
sns.boxplot(x=df["LoanAmount"])
plt.show()

# %%
sns.boxplot(x=df["ApplicantIncome"])
plt.show()

# %%
continous=["CoapplicantIncome","LoanAmount","Loan_Amount_Term","Credit_History","ApplicantIncome"]
disrete=["Gender","Married","Dependents","Education","Self_Employed","Property_Area","Loan_Status"]

# %%
sns.scatterplot(x=df["CoapplicantIncome"],y=df["LoanAmount"])
plt.show()

# %%
sns.scatterplot(x=df["LoanAmount"],y=df["Loan_Amount_Term"])
plt.show()

# %%
sns.scatterplot(x=df["Loan_Amount_Term"],y=df["Credit_History"])
plt.show()

# %%
sns.scatterplot(x=df["Credit_History"],y=df["ApplicantIncome"])
plt.show()

# %%
sns.scatterplot(x=df["ApplicantIncome"],y=df["Loan_Status"])
plt.show()

# %%
sns.pairplot(df,vars=continous)
plt.show()

# %%
plt.figure(figsize=(15,8))
sns.heatmap(df.corr(),annot=True,cmap="YlGnBu")
plt.title("correlation between features",size=20)
plt.show()

# %%
sns.countplot(x=df["Gender"])
plt.show()

# %%
sns.countplot(x=df["Married"])
plt.show()

# %%
sns.countplot(x=df["Dependents"])
plt.show()

# %%
sns.countplot(x=df["Education"])
plt.show()

# %%
sns.countplot(x=df["Self_Employed"])
plt.show()

# %%
sns.countplot(x=df["Property_Area"])
plt.show()

# %%
sns.countplot(x=df["Loan_Status"])
plt.show()

# %%
sns.jointplot(x="CoapplicantIncome",y="LoanAmount",data=df)
plt.show()

# %%
sns.jointplot(x="LoanAmount",y="Loan_Amount_Term",data=df)
plt.show()

# %%
sns.jointplot(x="Loan_Amount_Term",y="Credit_History",data=df)
plt.show()

# %%
sns.jointplot(x="Credit_History",y="ApplicantIncome",data=df)
plt.show()
